# %% [markdown]
# # xFeat & LighterGlue

# %%
# !uv pip install -e xfeat > /dev/null 2>&1

# %%
# !uv run -m xfeat.export_onnx > /dev/null 2>&1
# !uv run -m xfeat.export_coreml > /dev/null 2>&1

# %%
# !uv run -m xfeat.compare > /dev/null 2>&1

# %%
from IPython.display import Image

Image(filename="./xfeat/results/comparison_01.jpg")
