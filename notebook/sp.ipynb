# %% [markdown]
# # SuperPoint & LightGlue

# %%
# !uv pip install -e sp > /dev/null 2>&1

# %%
# !uv run -m sp.export_onnx > /dev/null 2>&1
# !uv run -m sp.export_coreml > /dev/null 2>&1

# %%
# !uv run -m sp.compare > /dev/null 2>&1

# %%
from IPython.display import Image

Image(filename="./sp/results/comparison_01.jpg")
